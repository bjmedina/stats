# %% [markdown]
# ### Bryan Medina - STA4364 - HW1
# # Q1
# ## Chapter 2 Problem 9
# ---

# %%
# necessary imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# read csv
df = pd.read_csv("Auto.csv")

# remove all the NA
auto_data = df.dropna()

# %% [markdown]
# ### a)
# - __Quantitative__: mpg, displacement, weight, acceleration
# - __Qualitative__: cylinders, year, horsepower, origin, name
#
# ### b)

# %%
# range of mpg quantitive predictor
print("Range of mpg predictor: [{}, {}]".format(min(auto_data['mpg']), max(auto_data['mpg'])))

# range of displacement quantitive predictor
print("Range of displacement predictor: [{}, {}]".format(min(auto_data['displacement']), max(auto_data['displacement'])))

# range of weight quantitive predictor
print("Range of weight predictor: [{}, {}]".format(min(auto_data['weight']), max(auto_data['weight'])))

# range of acceleration quantitive predictor
print("Range of acceleration predictor: [{}, {}]".format(min(auto_data['acceleration']), max(auto_data['acceleration'])))
# Out:
# Range of mpg predictor: [9.0, 46.6]
# Range of displacement predictor: [68.0, 455.0]
# Range of weight predictor: [1613, 5140]
# Range of acceleration predictor: [8.0, 24.8]

# %% [markdown]
# ### c)

# %%
# range of mpg quantitive predictor
print("Mpg predictor mean {} - standard deviation {}".format(np.mean(auto_data['mpg']), np.std(auto_data['mpg'])))

# range of displacement quantitive predictor
print("Displacement predictor mean {} - standard deviation {}".format(np.mean(auto_data['displacement']), np.std(auto_data['displacement'])))

# range of weight quantitive predictor
print("Weight predictor mean {} - standard deviation {}".format(np.mean(auto_data['weight']), np.std(auto_data['weight'])))

# range of acceleration quantitive predictor
print("Acceleration predictor mean {} - standard deviation {}".format(np.mean(auto_data['acceleration']), np.std(auto_data['acceleration'])))
# Out:
# Mpg predictor mean 23.51586901763224 - standard deviation 7.815941538224256
# Displacement predictor mean 193.53274559193954 - standard deviation 104.24803997948834
# Weight predictor mean 2970.2619647355164 - standard deviation 846.8355568478047
# Acceleration predictor mean 15.55566750629723 - standard deviation 2.746529639056109

# %% [markdown]
# ### d)

# %%
obs_to_delete = np.arange(10,86)
auto_data_mod = df.drop(obs_to_delete, axis=0)

# range of mpg quantitive predictor
print("Mpg predictor mean {} - standard deviation {}".format(np.mean(auto_data_mod['mpg']), np.std(auto_data_mod['mpg'])))

# range of displacement quantitive predictor
print("Displacement predictor mean {} - standard deviation {}".format(np.mean(auto_data_mod['displacement']), np.std(auto_data_mod['displacement'])))

# range of weight quantitive predictor
print("Weight predictor mean {} - standard deviation {}".format(np.mean(auto_data_mod['weight']), np.std(auto_data_mod['weight'])))

# range of acceleration quantitive predictor
print("Acceleration predictor mean {} - standard deviation {}".format(np.mean(auto_data_mod['acceleration']), np.std(auto_data_mod['acceleration'])))
# Out:
# Mpg predictor mean 24.44485981308411 - standard deviation 7.887612832492534
# Displacement predictor mean 187.17445482866043 - standard deviation 99.70889452054736
# Weight predictor mean 2933.183800623053 - standard deviation 808.3765473031685
# Acceleration predictor mean 15.709034267912774 - standard deviation 2.7022223464063075

# %% [markdown]
# ### e)

# %%
mpg    = auto_data['mpg']
disp   = auto_data['displacement']
weight = auto_data['weight']
acc    = auto_data['acceleration']

# Creating for subplots for plotting
fig, axes = plt.subplots(3, 2)
fig.set_size_inches(18.5, 10.5)

axes[0][0].set_title("Displacement vs MPG")
axes[0][0].scatter(mpg, disp)

axes[0][1].set_title("Weight vs MPG")
axes[0][1].scatter(mpg, weight)

axes[1][0].set_title("Acceleration vs MPG")
axes[1][0].scatter(mpg, acc)

axes[1][1].set_title("Weight vs Displacement")
axes[1][1].scatter(disp, weight)

axes[2][0].set_title("Acceleration vs Displacement")
axes[2][0].scatter(disp, acc)

axes[2][1].set_title("Acceleration vs Weight")
axes[2][1].scatter(weight, acc)

# %% [markdown]
# ### Comments
# ---
# Off first glance, it seems to me that acceleration and mpg, and acceleration and weight seem to not show any correlation with each other. On the other hand, Displacement and mpg, weight and mpg, weight and displacement, and acceleration and displacement seem to show some connection with each other, whether it be a positive relationship or a negative relationship.

# %% [markdown]
# ### f)
#
# My plot may suggest that weight may be the best predictor for mpg. This is because weight and mpg are highly correlated.

# %% [markdown]
# ## Chapter 3 Problem 9
# ---

# %%
# necessary imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# read csv
df = pd.read_csv("Auto.csv")

# remove all the NA
auto_data = df.dropna()

# %% [markdown]
# ### a)

# %%
# creating scatter matrix
scatter_matrix = pd.plotting.scatter_matrix(auto_data, alpha=0.2, figsize=(10,10))

# %% [markdown]
# ### b)

# %%
# correlations between all the variables using pandas "corr" function
auto_corr = auto_data.corr()
auto_corr
# Out:
#                    mpg  cylinders  displacement    weight  acceleration  \
# mpg           1.000000  -0.776260     -0.804443 -0.831739      0.422297
# cylinders    -0.776260   1.000000      0.950920  0.897017     -0.504061
# displacement -0.804443   0.950920      1.000000  0.933104     -0.544162
# weight       -0.831739   0.897017      0.933104  1.000000     -0.419502
# acceleration  0.422297  -0.504061     -0.544162 -0.419502      1.000000
# year          0.581469  -0.346717     -0.369804 -0.307900      0.282901
# origin        0.563698  -0.564972     -0.610664 -0.581265      0.210084
#
#                   year    origin
# mpg           0.581469  0.563698
# cylinders    -0.346717 -0.564972
# displacement -0.369804 -0.610664
# weight       -0.307900 -0.581265
# acceleration  0.282901  0.210084
# year          1.000000  0.184314
# origin        0.184314  1.000000

# %% [markdown]
# ### c)

# %%
from sklearn import linear_model

linear_reg = linear_model.LinearRegression()

# %% [markdown]
# # TO BE CONTINUED...
# # Q2

# %%
# necessary imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### a)

# %%
# read csv
df      = pd.read_csv("AirQuality.csv")
airqual = df.dropna()

# %%
num_bins = 100
pm25     = airqual['pm2.5']
x        = plt.hist(pm25, bins=num_bins)

# %%
# want to remove all zeros from the dataframe...
kill_value = 0
pm25_mod   = np.log(pm25[pm25 != kill_value])
x          = plt.hist(pm25_mod, bins=num_bins)

# %% [markdown]
# ### b)

# %%
# gathering predictors relating to time
years  = airqual['year']
months = airqual['month']
days   = airqual['day']
hours  = airqual['hour']

# %%
x = plt.scatter(years, pm25)

# %%
x = plt.scatter(months, pm25)

# %%
x = plt.scatter(days, pm25)

# %%
x = plt.scatter(hours, pm25)

# %% [markdown]
# # TO BE CONTINUED...
# ### c)

# %%
def transformation(x, tau):
    return (np.cos(2.*np.pi*x/tau), np.sin(2.*np.pi*x/tau))

tau = 24
transformation(hours, tau)

tau = 12
transformation(months, tau)

tau = 30
transformation(days, tau)
# Out:
# (24       0.913545
#  25       0.913545
#  26       0.913545
#  27       0.913545
#  28       0.913545
#  29       0.913545
#  30       0.913545
#  31       0.913545
#  32       0.913545
#  33       0.913545
#  34       0.913545
#  35       0.913545
#  36       0.913545
#  37       0.913545
#  38       0.913545
#  39       0.913545
#  40       0.913545
#  41       0.913545
#  42       0.913545
#  43       0.913545
#  44       0.913545
#  45       0.913545
#  46       0.913545
#  47       0.913545
#  48       0.809017
#  49       0.809017
#  50       0.809017
#  51       0.809017
#  52       0.809017
#  53       0.809017
#             ...
#  43794    1.000000
#  43795    1.000000
#  43796    1.000000
#  43797    1.000000
#  43798    1.000000
#  43799    1.000000
#  43800    0.978148
#  43801    0.978148
#  43802    0.978148
#  43803    0.978148
#  43804    0.978148
#  43805    0.978148
#  43806    0.978148
#  43807    0.978148
#  43808    0.978148
#  43809    0.978148
#  43810    0.978148
#  43811    0.978148
#  43812    0.978148
#  43813    0.978148
#  43814    0.978148
#  43815    0.978148
#  43816    0.978148
#  43817    0.978148
#  43818    0.978148
#  43819    0.978148
#  43820    0.978148
#  43821    0.978148
#  43822    0.978148
#  43823    0.978148
#  Name: day, Length: 41757, dtype: float64, 24       4.067366e-01
#  25       4.067366e-01
#  26       4.067366e-01
#  27       4.067366e-01
#  28       4.067366e-01
#  29       4.067366e-01
#  30       4.067366e-01
#  31       4.067366e-01
#  32       4.067366e-01
#  33       4.067366e-01
#  34       4.067366e-01
#  35       4.067366e-01
#  36       4.067366e-01
#  37       4.067366e-01
#  38       4.067366e-01
#  39       4.067366e-01
#  40       4.067366e-01
#  41       4.067366e-01
#  42       4.067366e-01
#  43       4.067366e-01
#  44       4.067366e-01
#  45       4.067366e-01
#  46       4.067366e-01
#  47       4.067366e-01
#  48       5.877853e-01
#  49       5.877853e-01
#  50       5.877853e-01
#  51       5.877853e-01
#  52       5.877853e-01
#  53       5.877853e-01
#               ...
#  43794   -1.133108e-15
#  43795   -1.133108e-15
#  43796   -1.133108e-15
#  43797   -1.133108e-15
#  43798   -1.133108e-15
#  43799   -1.133108e-15
#  43800    2.079117e-01
#  43801    2.079117e-01
#  43802    2.079117e-01
#  43803    2.079117e-01
#  43804    2.079117e-01
#  43805    2.079117e-01
#  43806    2.079117e-01
#  43807    2.079117e-01
#  43808    2.079117e-01
#  43809    2.079117e-01
#  43810    2.079117e-01
#  43811    2.079117e-01
#  43812    2.079117e-01
#  43813    2.079117e-01
#  43814    2.079117e-01
#  43815    2.079117e-01
#  43816    2.079117e-01
#  43817    2.079117e-01
#  43818    2.079117e-01
#  43819    2.079117e-01
#  43820    2.079117e-01
#  43821    2.079117e-01
#  43822    2.079117e-01
#  43823    2.079117e-01
#  Name: day, Length: 41757, dtype: float64)

# %% [markdown]
# # Q3
# ### a)

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x):
    'Function that we want to minimize'
    
    return -2*torch.exp((x[0]-1)**2 + (x[1]-1)**2) - torch.exp((x[0]+2)**2 + (x[1]+3)**2)

# %% [markdown]
# ### b)

# %%
x_1 = torch.tensor([0.0,0.0])
x_2 = torch.tensor([-1.0,-1.0])

# make an autograd variable for x (after performing operations with x, the gradient can be passed back to x)
x1 = torch.autograd.Variable(x_1, requires_grad=True)
x2 = torch.autograd.Variable(x_2, requires_grad=True)

x1_1 = []
x2_1 = []
x1_2 = []
x2_2 = []

# gradient descent parameters
step_sz    = 1e-11
print_step = 100
num_steps  = 4000

# for loop for iterative gradient descent
for step in range(num_steps):
    # get the gradient (torch.autograd.grad returns 1-element tuple so need to grab element 0 of the output)
    x_grad1 = torch.autograd.grad(f(x1), x1)[0]
    x_grad2 = torch.autograd.grad(f(x2), x2)[0]

    x1.data -= step_sz * x_grad1
    x2.data -= step_sz * x_grad2

    if step % print_step == 0:
        print("F1: {} \t F2: {}".format(x1.data, x2.data))
        
    x1_1.append(x1.data[0])
    x1_2.append(x1.data[1])
    x2_1.append(x2.data[0])
    x2_2.append(x2.data[1])
# Out:
# F1: tensor([1.7696e-05, 2.6545e-05]) 	 F2: tensor([-1.0000, -1.0000])
# F1: tensor([0.0018, 0.0027]) 	 F2: tensor([-1.0000, -1.0000])
# F1: tensor([0.0036, 0.0055]) 	 F2: tensor([-1.0000, -1.0000])
# F1: tensor([0.0055, 0.0083]) 	 F2: tensor([-1.0001, -1.0001])
# F1: tensor([0.0075, 0.0112]) 	 F2: tensor([-1.0001, -1.0001])
# F1: tensor([0.0094, 0.0142]) 	 F2: tensor([-1.0001, -1.0001])
# F1: tensor([0.0115, 0.0172]) 	 F2: tensor([-1.0001, -1.0001])
# F1: tensor([0.0136, 0.0204]) 	 F2: tensor([-1.0002, -1.0002])
# F1: tensor([0.0157, 0.0236]) 	 F2: tensor([-1.0002, -1.0002])
# F1: tensor([0.0180, 0.0269]) 	 F2: tensor([-1.0002, -1.0002])
# F1: tensor([0.0203, 0.0304]) 	 F2: tensor([-1.0002, -1.0002])
# F1: tensor([0.0226, 0.0339]) 	 F2: tensor([-1.0003, -1.0003])
# F1: tensor([0.0251, 0.0376]) 	 F2: tensor([-1.0003, -1.0003])
# F1: tensor([0.0276, 0.0414]) 	 F2: tensor([-1.0003, -1.0003])
# F1: tensor([0.0302, 0.0453]) 	 F2: tensor([-1.0003, -1.0003])
# F1: tensor([0.0329, 0.0494]) 	 F2: tensor([-1.0004, -1.0004])
# F1: tensor([0.0358, 0.0536]) 	 F2: tensor([-1.0004, -1.0004])
# F1: tensor([0.0387, 0.0580]) 	 F2: tensor([-1.0004, -1.0004])
# F1: tensor([0.0418, 0.0626]) 	 F2: tensor([-1.0004, -1.0004])
# F1: tensor([0.0449, 0.0674]) 	 F2: tensor([-1.0005, -1.0005])
# F1: tensor([0.0483, 0.0724]) 	 F2: tensor([-1.0005, -1.0005])
# F1: tensor([0.0518, 0.0777]) 	 F2: tensor([-1.0005, -1.0005])
# F1: tensor([0.0555, 0.0832]) 	 F2: tensor([-1.0005, -1.0005])
# F1: tensor([0.0594, 0.0890]) 	 F2: tensor([-1.0005, -1.0005])
# F1: tensor([0.0635, 0.0952]) 	 F2: tensor([-1.0006, -1.0006])
# F1: tensor([0.0678, 0.1017]) 	 F2: tensor([-1.0006, -1.0006])
# F1: tensor([0.0724, 0.1086]) 	 F2: tensor([-1.0006, -1.0006])
# F1: tensor([0.0774, 0.1161]) 	 F2: tensor([-1.0006, -1.0006])
# F1: tensor([0.0827, 0.1240]) 	 F2: tensor([-1.0007, -1.0007])
# F1: tensor([0.0884, 0.1327]) 	 F2: tensor([-1.0007, -1.0007])
# F1: tensor([0.0947, 0.1420]) 	 F2: tensor([-1.0007, -1.0007])
# F1: tensor([0.1015, 0.1523]) 	 F2: tensor([-1.0007, -1.0007])
# F1: tensor([0.1091, 0.1637]) 	 F2: tensor([-1.0008, -1.0008])
# F1: tensor([0.1176, 0.1764]) 	 F2: tensor([-1.0008, -1.0008])
# F1: tensor([0.1273, 0.1910]) 	 F2: tensor([-1.0008, -1.0008])
# F1: tensor([0.1385, 0.2078]) 	 F2: tensor([-1.0008, -1.0008])
# F1: tensor([0.1519, 0.2279]) 	 F2: tensor([-1.0009, -1.0009])
# F1: tensor([0.1686, 0.2528]) 	 F2: tensor([-1.0009, -1.0009])
# F1: tensor([0.1905, 0.2858]) 	 F2: tensor([-1.0009, -1.0009])
# F1: tensor([0.2232, 0.3348]) 	 F2: tensor([-1.0009, -1.0009])

# %% [markdown]
# ### c)

# %%
x1.data[1]
# Out:
# tensor(0.4321)

# %%
x1_1
# Out:
# [tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  tensor(0.2881),
#  ...]
